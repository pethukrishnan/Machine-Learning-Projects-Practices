# %%
# !pip install Pycaret

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pycaret.classification import *
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('data.csv')
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
# delete unnecessary columns

data = data.drop(columns=['id','Unnamed: 32'],axis=1)

# %%
data.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.countplot(data=data,x='diagnosis',hue='diagnosis')
# Out:
# <Axes: xlabel='diagnosis', ylabel='count'>

# %%
data_temp = data.drop(columns=['diagnosis'],axis=1)

# %%
fig,ax = plt.subplots(ncols=6,nrows=5,figsize=(20,20))
index=0
ax = ax.flatten()

for col in data_temp.columns:
    sns.kdeplot(data=data[col],ax=ax[index])
    index+=1
plt.tight_layout(pad=0.5,w_pad=0.7,h_pad=5.0)

# %%
fig,ax = plt.subplots(ncols=6,nrows=5,figsize=(20,20))
index=0
ax = ax.flatten()

for col in data_temp.columns:
    sns.boxplot(data=data[col],ax=ax[index])
    index+=1
plt.tight_layout(pad=0.5,w_pad=0.7,h_pad=5.0)

# %% [markdown]
# ## Create and Train the Model

# %%
# setup the data

clf = setup(data,target='diagnosis')
# Out:
# <style type="text/css">
# #T_69c98_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_69c98">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69c98_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_69c98_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69c98_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69c98_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_69c98_row0_col1" class="data row0 col1" >3615</td>
#     </tr>
#     <tr>
#       <th id="T_69c98_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_69c98_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_69c98_row1_col1" class="data row1 col1" >diagnosis</td>
#     </tr>
#     <tr>
#       <th id="T_69c98_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_7e938 th {
#   text-align: left;
# }
# ...

# %%
# select the best model

model =create_model('ada')
# Out:
# <style type="text/css">
# #T_69707_row10_col0, #T_69707_row10_col1, #T_69707_row10_col2, #T_69707_row10_col3, #T_69707_row10_col4, #T_69707_row10_col5, #T_69707_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_69707">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69707_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_69707_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_69707_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_69707_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_69707_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_69707_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_69707_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
# hyper parameter tuning

best_model = tune_model(model)
# Out:
# <style type="text/css">
# #T_b7ac0_row10_col0, #T_b7ac0_row10_col1, #T_b7ac0_row10_col2, #T_b7ac0_row10_col3, #T_b7ac0_row10_col4, #T_b7ac0_row10_col5, #T_b7ac0_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b7ac0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7ac0_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b7ac0_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b7ac0_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b7ac0_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b7ac0_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b7ac0_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b7ac0_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
